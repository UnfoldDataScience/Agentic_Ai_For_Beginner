# %% [raw]
# If you want to learn AWS step by step - Watch this playlist - https://www.youtube.com/watch?v=0SYV7o_fd50&list=PLmPJQXJiMoUWFW2JxRSAfhcsQ0Cr9qbv-
# 1. Install aws cli
# 2. Create an IAM user and give administrator access+Bedrock
# 3. Login through that user using AWS cli
# 4. Use boto3 and bedrock client to use on of foundation model
# 3. Get response in Python

# %%
import boto3

# %%
bedrock_runtime = boto3.client('bedrock-runtime', region_name='us-east-1')

# %%
prompt = "Hi tell me about making a good PPT for marketing"

kwargs = {
    "modelId": "amazon.titan-text-express-v1",
    "contentType": "application/json",
    "accept": "*/*",
    "body": json.dumps(
        {
            "inputText": prompt,
            "textGenerationConfig": {
                "maxTokenCount": 512,
                "temperature": 0,
                "topP": 0.9
            }
        }
    )
}

# %%
response = bedrock_runtime.invoke_model(**kwargs)

# %%
response_body = json.loads(response.get('body').read())
generation = response_body['results'][0]['outputText']

# %%
print(generation)
# Out:
# Here are some tips for making a good PPT for marketing:
#
# 1. Create a clear and concise presentation: Your presentation should have a clear and concise message that is easy to understand. Avoid using too much text or complex graphics that can distract from your message.
#
# 2. Use high-quality images: High-quality images can help to enhance your presentation and make it more visually appealing. Make sure to use images that are relevant to your topic and that are of good quality.
#
# 3. Use a consistent layout: Your presentation should have a consistent layout that is easy to follow. Use the same font, size, and color throughout your presentation to create a cohesive look.
#
# 4. Use bullet points: Bullet points can help to break down your information into manageable chunks. Use bullet points to highlight key points and to make your presentation more engaging.
#
# ...
